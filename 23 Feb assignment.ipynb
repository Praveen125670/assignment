# %% [markdown]
# ![image.png](attachment:c5404bb9-917d-4119-8c04-9b7d889717f2.png)

# %%
import pandas as pd

# %%
# Ans :
pd.Series([4, 8, 15, 16, 23, 42])
# Out:
# 0     4
# 1     8
# 2    15
# 3    16
# 4    23
# 5    42
# dtype: int64

# %% [markdown]
# ![image.png](attachment:bccae380-16ee-4bed-bfaf-721305785f2f.png)

# %%
#Ans:
k = [i for i in range(10,21)]
j = pd.Series(k)
print(j)
print(type(j))
# Out:
# 0     10
# 1     11
# 2     12
# 3     13
# 4     14
# 5     15
# 6     16
# 7     17
# 8     18
# 9     19
# 10    20
# dtype: int64
# <class 'pandas.core.series.Series'>

# %% [markdown]
# ![image.png](attachment:517fc338-ad00-49e9-8d2f-d517925d2a6c.png)

# %%
# Ans:
data={"Name" : ["Alice","Bob","Claire"] ,"Age": [25,30,27] , "Gender" : ["Female" , "Male" ,"Female"]}
pd.DataFrame(data, columns=["Name","Age","Gender"])
# Out:
#      Name  Age  Gender
# 0   Alice   25  Female
# 1     Bob   30    Male
# 2  Claire   27  Female

# %% [markdown]
# ![image.png](attachment:3e0eb520-10eb-4b7b-adfe-710fb1079203.png)

# %% [markdown]
# #Ans:
# '''pandas.series :
#               Series is a type of list in Pandas that can take integer values, string values, double values, and more.
#               But in Pandas Series we return an object in the form of a list, having an index starting from 0 to n, Where
#               n is the length of values in the series.
#
#  DataFrame:
#              Dataframe can be made of more than one series or we can say that a Dataframe is a collection of series that
#              can be used to analyze the data.
#
#
# Example:
#    pd.Series([4, 8, 15, 16, 23, 42]) #pandas series
#
#
#    data={"Name" : ["Alice","Bob","Claire"] ,"Age": [25,30,27] , "Gender" : ["Female" , "Male" ,"Female"]}   #pandas DataFrame
# pd.DataFrame(data, columns=["Name","Age","Gender"])

# %% [markdown]
# ![image.png](attachment:379ab170-5bf9-4e16-9411-2075654026ff.png)

# %% [markdown]
# #Ans:
# read()->read the dataframe:
#
# head()->number of rows to be displayed.
#
# shape()->Counting the rows and columns in DataFrame using shape()
#
# describe()->Summary of Statistics of DataFrame using describe() method.
#
# dropna()->Dropping the missing values in DataFrame, it can be done using the dropna() method, it removes all the NaN
#         values in the dataframe.
#
# merge()->Merging DataFrames using merge(), arguments passed are the dataframes to be merged along with the column name.
# etc

# %% [markdown]
# ![image.png](attachment:9a664b0a-20eb-4777-aa1d-560517ed7faa.png)

# %% [raw]
# #Ans:
# All Pandas data structures are value mutable (can be changed) and except Series all are size mutable. Series is size immutable.
# you can change the values but can't change the size of it.
# In DataFrame size and values are mutable.
# In panel also size and values are mutable.

# %% [markdown]
# ![image.png](attachment:be029656-3547-42ba-9aa8-a32804a71a69.png)

# %%
# Ans:
# panda series
data={"Name" : ["Alice","Bob","Claire"] ,
      "Age": [25,30,27] , 
      "Gender" : ["Female" , "Male" ,"Female"]}

# DataFrame
df=pd.DataFrame(data, columns=["Name","Age","Gender"])
df
# Out:
#      Name  Age  Gender
# 0   Alice   25  Female
# 1     Bob   30    Male
# 2  Claire   27  Female
