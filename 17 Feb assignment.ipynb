# %% [markdown]
# ![image.png](attachment:d453cc5c-a749-4441-a793-10c6f84f07ab.png)

# %%
Ans-> MongoDB is an open-source document-oriented database that is designed to store a large scale of data and also allows you to work with that data very efficiently.
      It is categorized under the NoSQL (Not only SQL) database because the storage and retrieval of data in the MongoDB are not in the form of tables. 
     
      A non-relational database, sometimes called NoSQL (Not Only SQL), is any kind of database that doesn’t use the tables, fields, and columns structured data concept 
      from relational databases. 
        
      However, non-relational databases still maintain some consistent advantages. If the data you are storing needs to be flexible in terms of shape or size,
      or if it needs to be open to change in future, then a non-relational database is the answer.and  SQL database is not flexible.

# %% [markdown]
# ![image.png](attachment:90ec744c-8c5f-480d-873a-453c8c5fb942.png)

# %%
Ans->Features of MongoDB include the following:

1.Replication. A replica set is two or more MongoDB instances used to provide high availability. Replica sets are made of primary and secondary servers. 
  The primary MongoDB server performs all the read and write operations, while the secondary replica keeps a copy of the data. If a primary replica fails,
  the secondary replica is then used.

2.Scalability. MongoDB supports vertical and horizontal scaling. Vertical scaling works by adding more power to an existing machine, 
  while horizontal scaling works by adding more machines to a user's resources.

3.Load balancing. MongoDB handles load balancing without the need for a separate, dedicated load balancer, through either vertical or horizontal scaling.

4.Schema-less. MongoDB is a schema-less database, which means the database can manage data without the need for a blueprint.

5.Document. Data in MongoDB is stored in documents with key-value pairs instead of rows and columns, which makes the data more flexible when compared to SQL databases.

# %% [markdown]
# ![image.png](attachment:2d740b9b-5228-479a-bc18-977dfed35449.png)

# %%
import pymongo

client = pymongo.MongoClient("mongodb+srv://praveenkumarpandey:golupandey420@cluster0.9e22zrs.mongodb.net/?retryWrites=true&w=majority")
db = client.test

# %%
pip install pymongo
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
client = pymongo.MongoClient("mongodb+srv://praveenkumarpandey:golupandey420@cluster0.9e22zrs.mongodb.net/?retryWrites=true&w=majority")

# %%
db
# Out:
# Database(MongoClient(host=['ac-svq6dre-shard-00-01.9e22zrs.mongodb.net:27017', 'ac-svq6dre-shard-00-00.9e22zrs.mongodb.net:27017', 'ac-svq6dre-shard-00-02.9e22zrs.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-deulny-shard-0', tls=True), 'test')

# %%
db=client['assign']

# %%
ass_submit=db["submitted"]

# %%
data1234=[
    {"name" : "praveen","submitted" : "yes"},
     {"name" : "sudh","submitted" : "no"},
     {"name" : "gangu","submitted" : "yes"},
     {"name" : "rahul","submitted": "no"}
]

# %% [markdown]
# ![Screenshot_20230405_113839.png](attachment:ef075a7e-a52f-47ee-8786-96dd8f97a304.png)

# %%
ass_submit.insert_many(data1234)

# %%
data12={"name": "pramod" ,"submitted":"yes"}

# %%
ass_submit.insert_one(data12)

# %%
for i in ass_submit.find():
    
    print(i)
# Out:
# {'_id': ObjectId('642d1e5e14020b6517bec9ba'), 'name': 'praveen', 'submitted': 'yes'}
# {'_id': ObjectId('642d1e5e14020b6517bec9bb'), 'name': 'sudh', 'submitted': 'no'}
# {'_id': ObjectId('642d1e5e14020b6517bec9bc'), 'name': 'gangu', 'submitted': 'yes'}
# {'_id': ObjectId('642d1e5e14020b6517bec9bd'), 'name': 'rahul', 'submitted': 'no'}
# {'_id': ObjectId('642d20af14020b6517bec9be'), 'name': 'pramod', 'submitted': 'yes'}
# {'_id': ObjectId('642d21af8359ed64b4416822'), 'name': 'praveen', 'submitted': 'yes'}
# {'_id': ObjectId('642d21af8359ed64b4416823'), 'name': 'sudh', 'submitted': 'no'}
# {'_id': ObjectId('642d21af8359ed64b4416824'), 'name': 'gangu', 'submitted': 'yes'}
# {'_id': ObjectId('642d21af8359ed64b4416825'), 'name': 'rahul', 'submitted': 'no'}
# {'_id': ObjectId('642d21b18359ed64b4416826'), 'name': 'pramod', 'submitted': 'yes'}
# {'_id': ObjectId('642d24458f7d0e4b512c5971'), 'name': 'praveen', 'submitted': 'yes'}
# ...

# %%
ass_submit.find_one()
# Out:
# {'_id': ObjectId('642d1e5e14020b6517bec9ba'),
#  'name': 'praveen',
#  'submitted': 'yes'}

# %% [markdown]
# ![image.png](attachment:1c8cca32-aea0-4ba5-af0f-b1780de7ab81.png)

# %%
Ans->In MongoDB, find() method is used to select documents in a collection and return a cursor to the selected documents. Cursor means a pointer that points to a document,
     when we use find() method it returns a pointer on the selected documents and returns one by one.
    
    eg:-

# %%
for i in ass_submit.find():
    print(i)
# Out:
# {'_id': ObjectId('642d1e5e14020b6517bec9ba'), 'name': 'praveen', 'submitted': 'yes'}
# {'_id': ObjectId('642d1e5e14020b6517bec9bb'), 'name': 'sudh', 'submitted': 'no'}
# {'_id': ObjectId('642d1e5e14020b6517bec9bc'), 'name': 'gangu', 'submitted': 'yes'}
# {'_id': ObjectId('642d1e5e14020b6517bec9bd'), 'name': 'rahul', 'submitted': 'no'}
# {'_id': ObjectId('642d20af14020b6517bec9be'), 'name': 'pramod', 'submitted': 'yes'}
# {'_id': ObjectId('642d21af8359ed64b4416822'), 'name': 'praveen', 'submitted': 'yes'}
# {'_id': ObjectId('642d21af8359ed64b4416823'), 'name': 'sudh', 'submitted': 'no'}
# {'_id': ObjectId('642d21af8359ed64b4416824'), 'name': 'gangu', 'submitted': 'yes'}
# {'_id': ObjectId('642d21af8359ed64b4416825'), 'name': 'rahul', 'submitted': 'no'}
# {'_id': ObjectId('642d21b18359ed64b4416826'), 'name': 'pramod', 'submitted': 'yes'}
# {'_id': ObjectId('642d24458f7d0e4b512c5971'), 'name': 'praveen', 'submitted': 'yes'}
# ...

# %% [markdown]
# ![image.png](attachment:fdf64f81-b92f-4feb-b8ad-550bc3391427.png)

# %%
Ans->The sort() method specifies the order in which the query returns the matching documents from the given collection.
    eg:-

# %%
for i in ass_submit.find():
    print(i)
# Out:
# {'_id': ObjectId('642d1e5e14020b6517bec9ba'), 'name': 'praveen', 'submitted': 'yes'}
# {'_id': ObjectId('642d1e5e14020b6517bec9bb'), 'name': 'sudh', 'submitted': 'no'}
# {'_id': ObjectId('642d1e5e14020b6517bec9bc'), 'name': 'gangu', 'submitted': 'yes'}
# {'_id': ObjectId('642d1e5e14020b6517bec9bd'), 'name': 'rahul', 'submitted': 'no'}
# {'_id': ObjectId('642d20af14020b6517bec9be'), 'name': 'pramod', 'submitted': 'yes'}
# {'_id': ObjectId('642d21af8359ed64b4416822'), 'name': 'praveen', 'submitted': 'yes'}
# {'_id': ObjectId('642d21af8359ed64b4416823'), 'name': 'sudh', 'submitted': 'no'}
# {'_id': ObjectId('642d21af8359ed64b4416824'), 'name': 'gangu', 'submitted': 'yes'}
# {'_id': ObjectId('642d21af8359ed64b4416825'), 'name': 'rahul', 'submitted': 'no'}
# {'_id': ObjectId('642d21b18359ed64b4416826'), 'name': 'pramod', 'submitted': 'yes'}
# {'_id': ObjectId('642d24458f7d0e4b512c5971'), 'name': 'praveen', 'submitted': 'yes'}
# ...

# %%
db.submitted.find().sort({"name":1})

# %% [markdown]
# ![image.png](attachment:809ac867-7088-4762-b043-25d6887c7e1f.png)

# %%
Ans-> The deleteOne() method deletes the first document from the collection that matches the given selection criteria. 
      It will delete/remove a single document from the collection.
    
    The drop() method removes collections from the database. It also removes all indexes associated with the dropped collection.
    The drop method accepts an optional document. It returns true if the collection dropped successfully. It takes one parameter which is optional.
    
    In MongoDB, you are allowed to delete the existing documents from the collection using db.collection.deleteMany() method. 
    This method deletes multiple documents from the collection according to the filter.
